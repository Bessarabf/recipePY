# %%
import numpy as np
import pandas as pd
import matplotlib
from scipy import signal
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def f(X):  
    T1=17.
    T2=70.
    a=sin((2.*pi/T2)*X)+1.*sin((2.*pi/T1)*X)    
    return a

# %%
N=256
t=arange(256)

# %%
y=zeros(N)
for i in range(N):
    y[i]=f(float(i))
Y=fft.fft(y)
subplot(211)
plot(t,y)
subplot(212)
plot(t,Y)
# Out:
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
width=arange(0.1,float(N)/10.,.5)

wmatr=signal.cwt(y,signal.ricker,width)
print size(wmatr)/256,len(width)
subplot(2,1,1)
contour(wmatr,30,cmap=cm.rainbow)
xticks(range(0,256,20))
subplot(2,1,2)
contourf(arange(N),3.5*width,wmatr,60,cmap=cm.rainbow)
xticks(range(0,256,20))
# Out:
# 51 51
# ([<matplotlib.axis.XTick at 0xf7dc130>,
# ...
#  <a list of 13 Text xticklabel objects>)
