# %%
import numpy
import matplotlib
from scipy.optimize import curve_fit
import scipy.signal as signal
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=loadtxt('1605a.txt',skiprows=1)
shape(data)
# Out:
# (102400L, 3L)

# %%
ix=200
iy=512
x=arange(0,200)
y=arange(0,256,0.5)
shape(y)
# Out:
# (512L,)

# %%
512*200
# Out:
# 102400

# %%
z=zeros(ix*iy).reshape(iy,ix)

# %%
k=0
for j in range(ix):
    for i in range(iy):
        z[i,j]=float(data[k,2]  )
        
        k=k+1

# %%
N=len(y)
freq=1./float(N)
zf=zeros(ix*iy).reshape(iy,ix)

# %%
# First, design the Buterworth filter
N  = 2    # Filter order
#Wn = 0.01 # Cutoff frequency
Wn=200.*freq
B, A = signal.butter(N, Wn, output='ba')
for i in range(len(x)):
    tempf = signal.filtfilt(B,A, z[:,i]) # Second, apply the filter
    zf[:,i]=tempf

# %%
ylim(255.5,0)
contourf(x,y,z,256,alpha=0.7,cmap=cm.nipy_spectral)
colorbar()

# %%
ylim(255.5,0)
contourf(x,y,zf,256,alpha=0.7,cmap=cm.nipy_spectral)
colorbar()
