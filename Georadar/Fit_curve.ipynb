# %%
import numpy as np
import matplotlib
from scipy.optimize import curve_fit

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def func(x, a, b, c):
    return a * np.exp(-b * x) + c

# %%
x = np.linspace(0,4,50)
y = func(x, 2.5, 1.3, 0.5)
yn = y + 0.2*np.random.normal(size=len(x))

# %%
plot(x,yn)

# %%
popt,pcov= curve_fit(func, x, yn)
print popt
print pcov
# Out:
# [ 2.55760379  1.34046851  0.52859772]
# [[ 0.0102995   0.00435115 -0.00050635]
#  [ 0.00435115  0.01294864  0.0035464 ]
#  [-0.00050635  0.0035464   0.0018705 ]]

# %%
# And then if you want to plot, you could do:
figure()
plot(x, yn, 'ko', label="Original Noised Data")
plot(x, func(x, *popt), 'r-', label="Fitted Curve")
legend()
