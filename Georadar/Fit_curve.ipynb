# %%
import numpy as np
import matplotlib
from scipy.optimize import curve_fit

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def func(x, a, b, c):
    return a * np.exp(-b * x) + c

# %%
x = np.linspace(0,4,50)
y = func(x, 2.5, 1.3, 0.5)
yn = y + 0.2*np.random.normal(size=len(x))

# %%
plot(x,yn)

# %%
popt,pcov= curve_fit(func, x, yn)
print(popt)
print (pcov)
# Out:
# [ 2.52238331  1.36013986 -1.00109338]
# [[ 0.01388958  0.00609348 -0.00065391]
#  [ 0.00609348  0.01821274  0.00476051]
#  [-0.00065391  0.00476051  0.00243454]]

# %%
# And then if you want to plot, you could do:
figure()
plot(x, yn, 'ko', label="Original Noised Data")
plot(x, func(x, *popt), 'r-', label="Fitted Curve")
legend()
