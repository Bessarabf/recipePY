# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import scipy.signal as signal
import numpy as np
# %matplotlib inline

# %%
# load foF2
data=np.loadtxt('AVD1976dayli_KLD.dat')
time=data[:,0]
foF2=data[:,1]
ntime=len(time)

# %%
# test fo LS
"""
time=np.arange(128)
ntime=len(time)
foF2=4.*np.sin(2.*np.pi/12.*time)
min_fraq=2.*np.pi/time[ntime-1]
max_fraq=2.*np.pi*1./(2.*dx)
frq = np.linspace(min_fraq, max_fraq, 100)
#frq=np.arange(1,ntime/2.)/ntime
#print(f)
"""
# Out:
# '\ntime=np.arange(128)\nntime=len(time)\nfoF2=4.*np.sin(2.*np.pi/12.*time)\nmin_fraq=2.*np.pi/time[ntime-1]\nmax_fraq=2.*np.pi*1./(2.*dx)\nfrq = np.linspace(min_fraq, max_fraq, 100)\n#frq=np.arange(1,ntime/2.)/ntime\n#print(f)\n'

# %%
fof2mean=np.mean(foF2)
Y = signal.lombscargle(time, foF2, frq)#,normalize=True)

fig, ax = plt.subplots(2, 1)
ax[0].plot(time,foF2)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')
ax[1].plot(frq,Y,'r') # plotting the spectrum
ax[1].set_xlabel('Freq (Hz)')
ax[1].set_ylabel('Y(freq)')
# Out:
# Text(0, 0.5, 'Y(freq)')

# %%
#Now make a plot of the input data:

plt.subplot(2, 1, 1)
plt.plot(time, foF2)

#Then plot the normalized periodogram:

plt.subplot(2, 1, 2)
plt.plot(2.*np.pi/frq,Y)
#plt.savefig("fig1.png")

# %%
per=np.zeros(int(ntime/2))
per=2.*np.pi/frq
plt.plot(per,Y,'r')
plt.xlim([10,40])
# Out:
# (10.0, 40.0)

# %% [markdown]
# ## WINDOW LS transform

# %%
print(per)
# Out:
# [127.          77.85139319  56.12946429  43.88481675  36.02578797
#   30.55407047  26.52531646  23.43522833  20.98998331  19.00680272
#   17.3660221   15.98601399  14.80918728  13.79374657  12.90862423
#   12.13024602  11.44040036  10.82479552  10.27205882   9.77302759
#    9.32023721   8.90754516   8.52985075   8.18288318   7.8630394
#    7.5672585    7.29292343   7.03778338   6.79989183   6.57755689
#    6.36930091   6.17382765   5.98999524   5.81679389   5.65332734
#    5.49879729   5.35249042   5.21376736   5.08205335   4.95683028
#    4.83762986   4.7240278    4.61563877   4.51211197   4.41312741
#    4.31839258   4.22763954   4.14062243   4.0571152    3.97690969
#    3.8998139    3.82565039   3.754255     3.6854756    3.61917098
#    3.55520995   3.49347041   3.43383859   3.37620838   3.32048065
#    3.26656274   3.21436789   3.1638148    3.1148272    3.0673335
#    3.02126637   2.9765625    2.93316225   2.89100943   2.850051
#    2.81023692   2.77151989   2.73385519   2.69720047   2.66151566
#    2.62676277   2.59290575   2.55991041   2.52774427   2.49637645
#    2.4657776    2.43591979   2.40677642   2.37832214   2.35053281
#    2.32338538   2.29685787   2.27092929   2.24557957   2.22078954
#    2.19654088   2.17281604   2.14959822   2.12687135   2.10462002
#    2.08282945   2.06148549   2.04057454   2.02008355   2.        ]

# %%
# window size in day
w_size=48
dx=1.
# number of points in windows
w_num=int(w_size/dx)
# number of  
w_frec=len(time)-1

# %%
# возможны пропуски в данных
bord=[]
i_st_end=np.zeros(2).astype(int)
jstart=0
jend=0
# search windows
for i in range(0,ntime-w_num-1): # цикл по всем точкам xt
   
    ix_start=i
    ix_end=i+w_num
    x_s=time[ix_start]
    x_e=time[ix_end]
    #print(i,x_s,x_e)
    #print(i_st_end)
    while(x_s > time[jstart]):
        jstart=jstart+1
        jend=jstart
        #print(jstart)
    while (x_e > time[jend]):
        jend=jend+1
        if(jend>w_frec):
            jend=w_frec
            break
         
        
    bord.append([jstart,jend])

# %%
w_spectr=len(bord)
#Убедимся, что частоты расчитываются по правилу 1.*d/N, 2*d/N ... (N/2-1)*d/N
win_fraq_min=2.*np.pi/w_size
win_fraq_max=2.*np.pi/(2.*dx)
#i_df=int((win_fraq_max-win_fraq_min)/win_fraq_min+0.5)
freq=np.linspace(min_fraq, max_fraq, 100)
#freq=np.arange(win_fraq_min,win_fraq_max,win_fraq_min)

#freq=np.arange(1,w_size/2.)/w_size
i_df=len(freq)
print(i_df,freq,len(bord))
m_LS=np.zeros(i_df*w_spectr).reshape(i_df,w_spectr)
# Out:
# 100 [0.0494739  0.08070742 0.11194095 0.14317447 0.17440799 0.20564151
#  0.23687504 0.26810856 0.29934208 0.3305756  0.36180913 0.39304265
#  0.42427617 0.4555097  0.48674322 0.51797674 0.54921026 0.58044379
#  0.61167731 0.64291083 0.67414436 0.70537788 0.7366114  0.76784492
#  0.79907845 0.83031197 0.86154549 0.89277901 0.92401254 0.95524606
#  0.98647958 1.01771311 1.04894663 1.08018015 1.11141367 1.1426472
#  1.17388072 1.20511424 1.23634777 1.26758129 1.29881481 1.33004833
#  1.36128186 1.39251538 1.4237489  1.45498242 1.48621595 1.51744947
#  1.54868299 1.57991652 1.61115004 1.64238356 1.67361708 1.70485061
#  1.73608413 1.76731765 1.79855117 1.8297847  1.86101822 1.89225174
#  1.92348527 1.95471879 1.98595231 2.01718583 2.04841936 2.07965288
#  2.1108864  2.14211993 2.17335345 2.20458697 2.23582049 2.26705402
#  2.29828754 2.32952106 2.36075458 2.39198811 2.42322163 2.45445515
#  2.48568868 2.5169222  2.54815572 2.57938924 2.61062277 2.64185629
#  2.67308981 2.70432333 2.73555686 2.76679038 2.7980239  2.82925743
#  2.86049095 2.89172447 2.92295799 2.95419152 2.98542504 3.01665856
#  3.04789209 3.07912561 3.11035913 3.14159265] 72

# %%
# massive of spectrogramm
# window LS transform

i=0
for gran in bord:
    i_st=gran[0]
    i_en=gran[1]
    foF2mean=np.mean(foF2[i_st:i_en])
    m_LS[0:i_df,i]=signal.lombscargle(time[i_st:i_en], foF2[i_st:i_en]-foF2mean, freq)#,normalize=True)
    i=i+1
    
print (np.shape(m_LS),np.shape(freq))
# Out:
# (100, 72) (100,)

# %%
print(len(time[:-w_num-1]),len(m_LS[0,:]),len(m_LS[:,0]),len(freq))
#lev=np.arange(8,16,2)
plt.contourf(time[1:-w_num-1],2.*np.pi/freq[:],m_LS[:,1:],levels=20,cmap=cm.rainbow)

plt.colorbar()
plt.savefig("LS"+str(w_size).format("6.2f")+".png")
# Out:
# 72 72 100 100

# %%
plt.plot(time[:-w_num-1],m_LS[3,:],'b+-')

# %%
print(1./freq)
# Out:
# [20.21267777 12.39043405  8.93328169  6.98448551  5.73368223  4.86283135
#   4.22163523  3.72983243  3.3406596   3.02502661  2.76388826  2.54425315
#   2.35695536  2.19534295  2.05447135  1.93058862  1.82079627  1.72281972
#   1.63484894  1.55542565  1.48336182  1.41767984  1.35756791  1.30234631
#   1.25144159  1.2043666   1.16070481  1.12009801  1.0822364   1.04685069
#   1.01370572  0.98259519  0.95333735  0.9257715   0.89975499  0.87516077
#   0.85187531  0.82979685  0.80883391  0.78890404  0.7699327   0.75185238
#   0.73460173  0.71812492  0.70237104  0.68729353  0.67284973  0.65900053
#   0.64570994  0.63294484  0.62067466  0.60887117  0.59750824  0.58656166
#   0.57600895  0.56582924  0.55600308  0.54651239  0.53734025  0.52847091
#   0.51988961  0.51158254  0.50353676  0.49574015  0.48818129  0.48084948
#   0.47373464  0.46682727  0.46011844  0.45359971  0.4472631   0.44110109
#   0.43510657  0.42927279  0.42359337  0.41806228  0.41267377  0.4074224
#   0.402303    0.39731065  0.39244069  0.38768868  0.38305036  0.37852173
#   0.37409892  0.36977827  0.36555628  0.36142962  0.35739509  0.35344963
#   0.34959034  0.34581441  0.34211918  0.33850209  0.33496068  0.3314926
#   0.32809561  0.32476752  0.32150628  0.31830989]
